# %%
import pandas as pd
import ast

# Lire le fichier CSV et charger les données dans un DataFrame
df = pd.read_csv('merged_file.csv')

# Supprimer les doublons du DataFrame
df = df.drop_duplicates()

# Supprimer les lignes avec des valeurs manquantes dans la colonne 'Language'
df = df.dropna(subset=['Language'])

# Remplacer les occurrences spécifiques dans la colonne 'contributors'
df['contributors'] = df['contributors'].replace("['The history or contributor list is too large to list contributors for this repository via the API.']", "[]")

# Remplir les valeurs manquantes dans la colonne 'Description' avec 'has no description'
df['Description'] = df['Description'].fillna("has no description")

# Convertir les chaînes de caractères représentant des listes en listes réelles pour les colonnes 'Topics', 'languages' et 'contributors'
df['Topics'] = df['Topics'].apply(ast.literal_eval)
df['languages'] = df['languages'].apply(ast.literal_eval)
df['contributors'] = df['contributors'].apply(ast.literal_eval)


import re

# Définir une fonction pour supprimer les emojis d'une chaîne de caractères
def remove_emojis(text):
    # Expression régulière pour trouver tous les emojis
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # émoticônes
                               u"\U0001F300-\U0001F5FF"  # symboles et pictogrammes
                               u"\U0001F680-\U0001F6FF"  # symboles de transport et cartes
                               u"\U0001F1E0-\U0001F1FF"  # drapeaux (iOS)
                               u"\U00002500-\U00002BEF"  # caractères chinois
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u200d"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\u3030"
                               u"\ufe0f"
                               "]+",
                               flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

# Appliquer la fonction remove_emojis à la colonne 'Description'
df['Description'] = df['Description'].apply(remove_emojis)

# Le DataFrame 'df' a été modifié avec les transformations précédentes
df
# Out:
#                       Name                                        Description
# 0             freeCodeCamp  freeCodeCamp.org's open-source codebase and cu...  \
# 5              public-apis                     A collective list of free APIs
# 6        developer-roadmap  Interactive roadmaps, guides and other educati...
# 7     system-design-primer  Learn how to design large-scale systems. Prep ...
# 8                    react     The library for web and native user interfaces
# ...                    ...                                                ...
# 2698             editor.js        A block-style editor with clean JSON output
# 2699               Hystrix  Hystrix is a latency and fault tolerance libra...
# 2700         awesome-swift  A collaborative list of awesome Swift librarie...
# 2701                   pkg    Package your Node.js project into an executable
# 2702              jellyfin                     The Free Software Media System
#
#        Stars                                                URL
# 0     369549       https://github.com/freeCodeCamp/freeCodeCamp  \
# 5     247051         https://github.com/public-apis/public-apis
# 6     243636  https://github.com/kamranahmedse/developer-roa...
# 7     223929  https://github.com/donnemartin/system-design-p...
# 8     210013                  https://github.com/facebook/react
# ...      ...                                                ...
# 2698   23467            https://github.com/codex-team/editor.js
# 2699   23465                 https://github.com/Netflix/Hystrix
# 2700   23463      https://github.com/matteocrippa/awesome-swift
# 2701   23454                      https://github.com/vercel/pkg
# 2702   23444               https://github.com/jellyfin/jellyfin
#
#              Date creation  Dernier modification  Forks    Language
# 0     2014-12-24T17:49:19Z  2023-07-06T10:34:34Z  32806  TypeScript  \
# 5     2016-03-20T23:49:42Z  2023-07-06T10:46:14Z  28345      Python
# 6     2017-03-15T13:45:52Z  2023-07-06T10:42:38Z  34240  TypeScript
# 7     2017-02-26T16:15:28Z  2023-07-06T10:35:11Z  39662      Python
# 8     2013-05-24T16:15:54Z  2023-07-06T10:36:32Z  43969  JavaScript
# ...                    ...                   ...    ...         ...
# 2698  2015-11-28T20:56:35Z  2023-07-06T10:04:56Z   1791  TypeScript
# 2699  2012-11-19T20:14:46Z  2023-07-06T06:42:21Z   4710        Java
# 2700  2014-07-10T14:04:09Z  2023-07-06T06:29:10Z   3051        Ruby
# 2701  2016-08-08T19:41:59Z  2023-07-06T10:29:54Z   1005  JavaScript
# 2702  2018-12-09T06:36:45Z  2023-07-06T10:33:34Z   2147          C#
#
#                                                  Topics
# 0     [careers, certification, community, curriculum...  \
# 5     [api, apis, dataset, development, free, list, ...
# 6     [angular-roadmap, backend-roadmap, blockchain-...
# 7     [design, design-patterns, design-system, devel...
# 8     [declarative, frontend, javascript, library, r...
# ...                                                 ...
# 2698  [codex-editor, editor, javascript, json, redac...
# 2699                                                 []
# 2700  [awesome, awesome-list, awesome-lists, awesome...
# 2701                  [binaries, cli, compiler, nodejs]
# 2702          [csharp, dotnet, hacktoberfest, jellyfin]
#
#                                               languages
# 0     [TypeScript, JavaScript, CSS, MDX, Dockerfile,...  \
# 5                                       [Python, Shell]
# 6                  [TypeScript, Astro, JavaScript, CSS]
# 7                                       [Python, Shell]
# 8     [JavaScript, HTML, CSS, C++, TypeScript, Coffe...
# ...                                                 ...
# 2698                [TypeScript, HTML, CSS, JavaScript]
# 2699                       [Java, Clojure, CSS, Groovy]
# 2700                                             [Ruby]
# 2701  [JavaScript, TypeScript, CSS, HTML, Pug, Coffe...
# 2702       [C#, Shell, HTML, Dockerfile, Makefile, CSS]
#
#                                            contributors
# 0     [{'login': 'raisedadead', 'contributions': 142...
# 5     [{'login': 'matheusfelipeog', 'contributions':...
# 6     [{'login': 'kamranahmedse', 'contributions': 1...
# 7     [{'login': 'donnemartin', 'contributions': 175...
# 8     [{'login': 'zpao', 'contributions': 1778, 'typ...
# ...                                                 ...
# 2698  [{'login': 'khaydarov', 'contributions': 202, ...
# 2699  [{'login': 'mattrjacobs', 'contributions': 538...
# 2700  [{'login': 'READMEbot', 'contributions': 733, ...
# 2701  [{'login': 'igorklopov', 'contributions': 887,...
# 2702  [{'login': 'LukePulverenti', 'contributions': ...
#
# [2313 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Description', 'Stars', 'URL', 'Date creation',
#        'Dernier modification', 'Forks', 'Language', 'Topics', 'languages',
#        'contributors'],
#       dtype='object')

# %%
import mysql.connector

# Établir une connexion à la base de données MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="github"
)

# Créer un curseur
cursor = conn.cursor()

# Code SQL pour créer les tables avec des index
sql_code = """
DROP TABLE IF EXISTS RepoTopic;
DROP TABLE IF EXISTS RepoContributor;
DROP TABLE IF EXISTS RepoLanguage;
DROP TABLE IF EXISTS Language;
DROP TABLE IF EXISTS Topic;
DROP TABLE IF EXISTS Contributor;
DROP TABLE IF EXISTS Repo;

CREATE TABLE Repo (
    id INT PRIMARY KEY AUTO_INCREMENT,
    Name VARCHAR(255),
    Description LONGTEXT,
    Stars INT,
    URL VARCHAR(255),
    DateCreation DATE,
    LastModification DATE,
    Forks INT,
    INDEX idx_Name (Name),
    INDEX idx_Stars (Stars),
    INDEX idx_DateCreation (DateCreation),
    INDEX idx_LastModification (LastModification)
);

CREATE TABLE Contributor (
    id INT PRIMARY KEY AUTO_INCREMENT,
    login VARCHAR(255),
    INDEX idx_login (login)
);

CREATE TABLE Topic (
    id INT PRIMARY KEY AUTO_INCREMENT,
    name VARCHAR(255),
    INDEX idx_name (name)
);

CREATE TABLE Language (
    id INT PRIMARY KEY AUTO_INCREMENT,
    name VARCHAR(255),
    INDEX idx_name (name)
);

CREATE TABLE RepoLanguage (
    repo_id INT,
    language_id INT,
    FOREIGN KEY (repo_id) REFERENCES Repo(id),
    FOREIGN KEY (language_id) REFERENCES Language(id),
    is_main BOOLEAN,
    INDEX idx_repo_id (repo_id),
    INDEX idx_language_id (language_id)
);

CREATE TABLE RepoContributor (
    repo_id INT,
    contributor_id INT,
    contributions INT,
    FOREIGN KEY (repo_id) REFERENCES Repo(id),
    FOREIGN KEY (contributor_id) REFERENCES Contributor(id),
    INDEX idx_repo_id (repo_id),
    INDEX idx_contributor_id (contributor_id)
);

CREATE TABLE RepoTopic (
    topic_id INT,
    repo_id INT,
    FOREIGN KEY (topic_id) REFERENCES Topic(id),
    FOREIGN KEY (repo_id) REFERENCES Repo(id),
    INDEX idx_topic_id (topic_id),
    INDEX idx_repo_id (repo_id)
);
"""

# Exécuter le code SQL
for statement in sql_code.split(";"):
    if statement.strip() != "":
        cursor.execute(statement)

# Valider les changements dans la base de données
conn.commit()

# Fermer le curseur et la connexion
cursor.close()
conn.close()

print('Terminé')
# Out:
# Terminé

# %%
import mysql.connector
from datetime import datetime

# Établir une connexion à la base de données MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="github"
)

# Créer un curseur
cursor = conn.cursor()

# Insérer des données à partir du DataFrame
for _, row in df.iterrows():
    # Insérer les données Repo
    repo_data = {
        "Name": row['Name'],
        "Description": row['Description'],
        "Stars": row['Stars'],
        "URL": row['URL'],
        "DateCreation": datetime.strptime(row['Date creation'], '%Y-%m-%dT%H:%M:%SZ').date(),
        "LastModification": datetime.strptime(row['Dernier modification'], '%Y-%m-%dT%H:%M:%SZ').date(),
        "Forks": row['Forks']
    }
    
    print(repo_data['Description'])

    repo_insert_query = """
    INSERT INTO Repo (Name, Description, Stars, URL, DateCreation, LastModification, Forks)
    VALUES (%(Name)s, %(Description)s, %(Stars)s, %(URL)s, %(DateCreation)s, %(LastModification)s, %(Forks)s)
    """
    cursor.execute(repo_insert_query, repo_data)

    repo_id = cursor.lastrowid
    
    # *---- Début Insérer des Langages ----*
    languages = row['languages']
    language_ids = {}

    language_insert_query = """
    INSERT INTO Language (name)
    VALUES (%s)
    """
    for language in languages:
        language_id_query = "SELECT id FROM Language WHERE name = %s"
        cursor.execute(language_id_query, (language,))
        result = cursor.fetchone()
        if result:
            language_id = result[0]
        else:
            cursor.execute(language_insert_query, (language,))
            language_id = cursor.lastrowid
        language_ids[language] = language_id
        
            # Insérer RepoLanguage
    repo_language_insert_query = """
    INSERT INTO RepoLanguage (repo_id, language_id,is_main)
    VALUES (%s, %s, %s)
    """
    
    for language in language_ids:
        is_main = (language_ids[language] == row['Language'])
        cursor.execute(repo_language_insert_query, (repo_id, language_ids[language],is_main))
    
    # !---- Fin Insérer des Langages ----!
    
    # *---- Début Insérer des Sujets ----*
    topics = row['Topics']
    topic_ids = {}

    topic_insert_query = """
    INSERT INTO Topic (name)
    VALUES (%s)
    """
    for topic in topics:
        topic_id_query = "SELECT id FROM Topic WHERE name = %s"
        cursor.execute(topic_id_query, (topic,))
        result = cursor.fetchone()
        if result:
            topic_id = result[0]
        else:
            cursor.execute(topic_insert_query, (topic,))
            topic_id = cursor.lastrowid
        topic_ids[topic] = topic_id

            # Insérer RepoTopic
    repo_topic_insert_query = """
    INSERT INTO RepoTopic (repo_id, topic_id)
    VALUES (%s, %s)
    """

    for topic in topic_ids:
        cursor.execute(repo_topic_insert_query, (repo_id, topic_ids[topic]))

    # !---- Fin Insérer des Sujets ----!

    # *---- Début Insérer des Contributeurs ----*
    contributors = row['contributors']
    contributor_ids = {}

    contributor_insert_query = """
    INSERT INTO Contributor (login)
    VALUES (%s)
    """

    for contributor in contributors:
        login = contributor['login']
        contributions = contributor['contributions']
        contributor_id_query = "SELECT id FROM Contributor WHERE login = %s"
        cursor.execute(contributor_id_query, (login,))
        result = cursor.fetchone()
        if result:
            contributor_id = result[0]
        else:
            cursor.execute(contributor_insert_query, (login,))
            contributor_id = cursor.lastrowid
        contributor_ids[login] = {"contributor_id":contributor_id,"contributions":contributions}



    # Insérer RepoContributor
    repo_contributor_insert_query = """
    INSERT INTO RepoContributor (repo_id, contributor_id, contributions)
    VALUES (%s, %s, %s)
    """
    for contributor in contributor_ids:
        cursor.execute(repo_contributor_insert_query, (repo_id, contributor_ids[contributor]['contributor_id'], contributor_ids[contributor]['contributions']))

    # ---- Fin Insérer des Contributeurs ---!

    print("_", _)
#     if _ == 20:
#         break

# Valider les changements dans la base de données
conn.commit()

# Fermer le curseur et la connexion
cursor.close()
conn.close()
# Out:
# freeCodeCamp.org's open-source codebase and curriculum. Learn to code for free.
# _ 0
# A collective list of free APIs
# _ 5
# Interactive roadmaps, guides and other educational content to help developers grow in their careers.
# _ 6
# Learn how to design large-scale systems. Prep for the system design interview.  Includes Anki flashcards.
# _ 7
# The library for web and native user interfaces
# _ 8
# This is the repo for Vue 2. For Vue 3, go to https://github.com/vuejs/core
# _ 10
# An Open Source Machine Learning Framework for Everyone
# _ 11
# A curated list of awesome Python frameworks, libraries, software and resources
# _ 12
#  Algorithms and data structures implemented in JavaScript with explanations and links to further readings
# _ 13
# The most popular HTML, CSS, and JavaScript framework for developing responsive, mobile first projects on the web.
# _ 16
# All Algorithms implemented in Python
# _ 17
#    A delightful community-driven (with 2,100+ contributors) framework for managing your zsh configuration. Includes 300+ optional plugins (rails, git, macOS, hub, docker, homebrew, node, php, python, etc), 140+ themes to spice up your morning, and an auto-update tool so that makes it easy to keep up with the latest updates from the community.
# _ 18
# Flutter makes it easy and fast to build beautiful apps for mobile and beyond
# _ 19
# Linux kernel source tree
# _ 20
# Visual Studio Code
# _ 22
# An experimental open-source attempt to make GPT-4 fully autonomous.
# _ 24
# A list of Free Software network services and web applications which can be hosted on your own servers
# _ 25
# Python - 100
# _ 27
# JavaScript Style Guide
# _ 28
# Java+ Java  Java  JavaGuide
# _ 29
# Command-line program to download videos from YouTube.com and other video sites
# _ 30
#  labuladong English version supported! Crack LeetCode, not only how, but also why.
# _ 31
# Short code snippets for all your development needs
# _ 32
# The Go programming language
# _ 33
# A framework for building native applications using React
# _ 34
# The React Framework
# _ 36
# :electron: Build cross-platform desktop apps with JavaScript, HTML, and CSS
# _ 37
#  Transformers: State-of-the-art Machine Learning for Pytorch, TensorFlow, and JAX.
# _ 38
# Bring data to life with SVG, Canvas and HTML. :bar_chart::chart_with_upwards_trend::tada:
# _ 39
# A curated list of awesome Go frameworks, libraries and software
# _ 40
# Promise based HTTP client for the browser and node.js
# _ 43
# Set up a modern web app by running one command.
# _ 44
# Production-Grade Container Scheduling and Management
# _ 45
# Node.js JavaScript runtime :sparkles::turtle::rocket::sparkles:
# _ 46
# JavaScript 3D Library.
# _ 47
#  Curated coding interview preparation materials for busy software engineers
# _ 48
# Windows system utilities to maximize productivity
# _ 49
# TypeScript is a superset of JavaScript that compiles to clean JavaScript output.
# _ 50
# :white_check_mark:  The Node.js best practices list (May 2023)
# _ 51
# A modern runtime for JavaScript and TypeScript.
# _ 52
# The new Windows Terminal and the original Windows console host, all in the same place!
# _ 53
# The modern web developer’s platform
# _ 54
# Stable Diffusion web UI
# _ 55
# MUI Core: Ready-to-use foundational React components, free forever. It includes Material UI, which implements Google's Material Design.
# _ 56
# Display and control your Android device
# _ 57
# An enterprise-class UI design language and React UI library
# _ 58
# Node.js API for Chrome
# _ 59
# :bathtub: Clean Code concepts adapted for JavaScript
# _ 60
# Empowering everyone to build reliable and efficient software.
# _ 61
# :tada: A magical vue admin                                                                https://panjiachen.github.io/vue-element-admin
# _ 62
# This repo includes ChatGPT prompt curation to use ChatGPT better.
# _ 63
# Design patterns implemented in Java
# _ 64
# Storybook is a frontend workshop for building UI components and pages in isolation. Made for UI development, testing, and documentation.
# _ 65
#  A cross-browser library of CSS animations. As easy to use as an easy thing.
# _ 66
# Magnificent app which corrects your previous console command.
# _ 67
# Models and examples built with TensorFlow
# _ 68
# "The mother of all demo apps" — Exemplary fullstack Medium.com clone powered by React, Angular, Node, Django, and many more
# _ 69
# Papers from the computer science community to read and discuss.
# _ 70
# Laravel is a web application framework with expressive, elegant syntax. We’ve already laid the foundation for your next big idea — freeing you to create without sweating the small things.
# _ 71
# Demonstrate all the questions on LeetCode in the form of animation.LeetCode
# _ 72
# 24 Lessons, 12 Weeks, Get Started as a Web Developer
# _ 73
# The Web framework for perfectionists with deadlines.
# _ 75
# The iconic SVG, font, and CSS toolkit
# _ 76
# A list of SaaS, PaaS and IaaS offerings that have free tiers of interest to devops and infradev
# _ 77
# :octocat:  GitHub Share interesting, entry-level open source projects on GitHub.
# _ 78
# Free monospaced font with programming ligatures
# _ 79
#  Core Interview Questions & Answers For Experienced Java(Backend) Developers |  Java
# _ 80
# Cybernetically enhanced web apps
# _ 81
# Bitcoin Core integration/staging tree
# _ 82
# A utility-first CSS framework for rapid UI development.
# _ 83
# Gin is a HTTP web framework written in Go (Golang). It features a Martini-like API with much better performance -- up to 40 times faster. If you need smashing performance, get yourself some Gin.
# _ 84
# Open Source Computer Vision Library
# _ 85
# A fast reverse proxy to help you expose a local server behind a NAT or firewall to the internet.
# _ 86
# Tensors and Dynamic neural networks in Python with strong GPU acceleration
# _ 88
# Node Version Manager - POSIX-compliant bash script to manage multiple active node.js versions
# _ 89
# Spring Boot
# _ 90
# The world’s fastest framework for building websites.
# _ 91
# Get a full fake REST API with zero coding in less than 30 seconds (seriously)
# _ 92
# mallSpringBoot+MyBatisDocker
# _ 93
# Vim-fork focused on extensibility and usability
# _ 94
# Moby Project - a collaborative project for the container ecosystem to assemble container-based systems
# _ 96
# Build smaller, faster, and more secure desktop applications with a web frontend.
# _ 97
# Collection of publicly available IPTV channels from all over the world
# _ 98
#  Consolidating and extending hosts files from several well-curated sources. Optionally pick extensions for porn, social media, and other categories.
# _ 100
# Make Your Company Data Driven. Connect to any data source, easily visualize, dashboard and share your data.
# _ 101
# Reactive Programming in Swift
# _ 102
# Productive & portable high-performance programming in Python.
# _ 103
# Free and open source manga reader for Android.
# _ 105
# A privacy-first, open-source platform for knowledge management and collaboration. Download link:  http://github.com/logseq/logseq/releases. roadmap: http://trello.com/b/8txSM12G/roadmap
# _ 106
# flutter  APP flutter  140+ demo
# _ 107
# TypeScript-first schema validation with static type inference
# _ 108
# A post-modern modal text editor.
# _ 109
# Go configuration with fangs
# _ 110
# Visualizer for neural network, deep learning, and machine learning models
# _ 111
#  It has never been so easy to document your things!
# _ 112
# GitLab CE Mirror | Please open new issues in our issue tracker on GitLab.com
# _ 114
#  Nextcloud server, a safe home for all your data
# _ 115
# Flexible authentication solution for Rails with Warden.
# _ 116
# OpenFaaS - Serverless Functions Made Simple
# _ 117
# Over 250 terminal color schemes/themes for iTerm/iTerm2. Includes ports to Terminal, Konsole, PuTTY, Xresources, XRDB, Remmina, Termite, XFCE, Tilda, FreeBSD VT, Terminator, Kitty, MobaXterm, LXTerminal, Microsoft's Windows Terminal, Visual Studio, Alacritty
# _ 118
# Mask R-CNN for object detection and instance segmentation on Keras and TensorFlow
# _ 120
# A platform for building proxies to bypass network restrictions.
# _ 122
#  A React renderer for Three.js
# _ 123
# :ram: Practical functional Javascript
# _ 124
# Easily and securely send things from one computer to another :crocodile: :package:
# _ 125
# Glances an Eye on your system. A top/htop alternative for GNU/Linux, BSD, Mac OS and Windows operating systems.
# _ 126
# A set of small, responsive CSS modules that you can use in every web project.
# _ 127
# A community-driven Emacs distribution - The best editor is neither Emacs nor Vim,  it's Emacs *and* Vim!
# _ 128
# Introspected tunnels to localhost
# _ 129
# Find and fix problems in your JavaScript code.
# _ 130
# Launcher for Windows, an alternative to Alfred and Launchy.
# _ 131
# A library for efficient similarity search and clustering of dense vectors.
# _ 132
# I am using this repository to document my journey learning about DevOps. I began this process on January 1, 2022, and plan to continue until March 31. I will be dedicating one hour each day, including weekends, to gaining a foundational understanding of the various aspects of DevOps. This will be a 90-day intensive study period. 2022 & 2023 inc.
# _ 134
# JavaScript image gallery for mobile and desktop, modular, framework independent
# _ 135
#  A server-side Swift HTTP web framework.
# _ 136
# Streisand sets up a new server running your choice of WireGuard, OpenConnect, OpenSSH, OpenVPN, Shadowsocks, sslh, Stunnel, or a Tor bridge. It also generates custom instructions for all of these services. At the end of the run you are given an HTML file with instructions that can be shared with friends, family members, and fellow activists.
# _ 137
# An open autonomous driving platform
# _ 138
# CodeHub is an iOS application written using Xamarin
# _ 139
# Nodejs extension host for vim & neovim, load extensions like VSCode and host language servers.
# _ 140
# Deezer source separation library including pretrained models.
# _ 142
# Official React bindings for Redux
# _ 143
# Structured, pluggable logging for Go.
# _ 144
# Samples for Android Architecture Components.
# _ 145
# This is a fun, new monospaced font that includes programming ligatures and is designed to enhance the modern look and feel of the Windows Terminal.
# _ 146
#  Command line video player
# _ 147
# Termux - a terminal emulator application for Android OS extendible by variety of packages.
# _ 148
# Investment Research for Everyone, Everywhere.
# _ 149
# Minimal examples of data structures and algorithms in Python
# _ 150
#  Empowering JavaScript with native platform APIs.  Best of all worlds (TypeScript, Swift, Objective C, Kotlin, Java). Use what you love  Angular, Capacitor, Ionic, React, Solid, Svelte, Vue with: SwiftUI, Jetpack Compose, Flutter and you name it compatible.
# _ 151
#  A curated list of delightful VS Code packages and resources.
# _ 153
#       The most popular, free and open-source Tailwind CSS component library
# _ 154
# Realtime MVC Framework for Node.js
# _ 155
# Learn and understand Docker&Container technologies, with real DevOps practice!
# _ 156
#  Text-Prompted Generative Audio Model
# _ 157
# Mostly adequate guide to FP (in javascript)
# _ 158
#  Control your display's brightness & volume on your Mac as if it was a native Apple Display. Use Apple Keyboard keys or custom shortcuts. Shows the native macOS OSDs.
# _ 160
# OpenZeppelin Contracts is a library for secure smart contract development.
# _ 161
# Standard Library
# _ 162
# Guzzle, an extensible PHP HTTP client
# _ 163
# Routing and navigation for your React Native apps
# _ 164
# The simplest, fastest repository for training/finetuning medium-sized GPTs.
# _ 165
# Cross-platform, customizable ML solutions for live and streaming media.
# _ 166
# Backstage is an open platform for building developer portals
# _ 167
# GitHub on steroids
# _ 168
# A frontend Framework for building B2B applications running in the browser on top of REST/GraphQL APIs, using ES6, React and Material Design
# _ 169
#  LeetCode solutions in any programming language |  LeetCode Offer 2  6
# _ 170
# A command-line tool that makes git easier to use with GitHub.
# _ 171
# An alternative side effect model for Redux apps
# _ 172
#  Offline storage, improved. Wraps IndexedDB, WebSQL, or localStorage using a simple but powerful API.
# _ 173
# stb single-file public domain libraries for C/C++
# _ 174
# A V2Ray client for Android, support Xray core and v2fly core
# _ 175
# Ember.js - A JavaScript framework for creating ambitious web applications
# _ 176
# Curated list of Go design patterns, recipes and idioms
# _ 177
# A React framework for building text editors.
# _ 178
# We have made you a wrapper you can't refuse
# _ 180
# Cloud-native high-performance edge/middle/service proxy
# _ 181
# Free, open source crypto trading bot
# _ 182
# Penpot - The Open-Source design & prototyping platform
# _ 183
# Telegram for Android source
# _ 184
# A beautiful replacement for JavaScript's "alert"
# _ 185
# DeepSpeech is an open source embedded (offline, on-device) speech-to-text engine which can run in real time on devices ranging from a Raspberry Pi 4 to high power GPU servers.
# _ 186
# Scripts to build your own IPsec VPN server, with IPsec/L2TP, Cisco IPsec and IKEv2
# _ 187
# Machine Learning From Scratch. Bare bones NumPy implementations of machine learning models and algorithms with a focus on accessibility. Aims to cover everything from linear regression to deep learning.
# _ 189
# HTML5 FLV Player
# _ 190
# A Java serialization/deserialization library to convert Java Objects into JSON and back
# _ 191
#
# _ 192
# IDE-style autocomplete for your existing terminal & shell
# _ 194
# TLS/SSL and crypto library
# _ 195
# Telegram Desktop messaging app
# _ 196
# The Modern Data Stack  — Directus is an instant REST+GraphQL API and intuitive no-code data collaboration app for any SQL database.
# _ 197
# A modern replacement for ‘ls’.
# _ 198
# SRS is a simple, high-efficiency, real-time video server supporting RTMP, WebRTC, HLS, HTTP-FLV, SRT, MPEG-DASH, and GB28181.
# _ 199
# Lightweight, user-friendly onboarding tour library
# _ 201
# has no description
# _ 202
# APM, Application Performance Monitoring System
# _ 203
# One second to read GitHub code with VS Code.
# _ 204
# The better way to deal with JSON data in Swift.
# _ 205
# 50
# _ 206
# Adds static typing to JavaScript to improve developer productivity and code quality.
# _ 207
# Incremental bundler and build system optimized for JavaScript and TypeScript, written in Rust – including Turbopack and Turborepo.
# _ 208
# The web's most popular Jamstack front-end template (boilerplate) for building web applications with React
# _ 209
# Deprecated - Chosen is a library for making long, unwieldy select boxes more friendly.
# _ 210
# Secure and fast microVMs for serverless computing.
# _ 211
# Our original Web Component library.
# _ 212
# Animated sprite editor & pixel art tool (Windows, macOS, Linux)
# _ 213
# Build your personal knowledge base with Trilium Notes
# _ 214
#  Headless UI for building powerful tables & datagrids for TS/JS -  React-Table, Vue-Table, Solid-Table, Svelte-Table
# _ 215
#  Windows 95 in Electron. Runs on macOS, Linux, and Windows.
# _ 216
# Javascript audio library for the modern web.
# _ 217
# :partly_sunny: The right way to check the weather
# _ 218
# Distributed Task Queue (development branch)
# _ 219
# Cross-platform asynchronous I/O
# _ 220
# Elixir is a dynamic, functional language for building scalable and maintainable applications
# _ 222
# Bootstrap components built with React
# _ 223
# The Google I/O Android App
# _ 224
# The user-friendly command line shell.
# _ 225
# Repository to track the progress in Natural Language Processing (NLP), including the datasets and the current state-of-the-art for the most common NLP tasks.
# _ 228
# A modern and intuitive terminal-based text editor
# _ 229
#   Comprehensive and exhaustive JavaScript & Node.js testing best practices (June 2023)
# _ 230
# JavaScript syntax highlighter with language auto-detection and zero dependencies.
# _ 231
# Write scalable load tests in plain Python
# _ 232
#  Minimalistic Vue-powered static site generator
# _ 233
# The Cyber Swiss Army Knife - a web app for encryption, encoding, compression and data analysis
# _ 234
# Desktop/Android/HTML5/iOS Java game development framework
# _ 235
# Move and resize windows on macOS with keyboard shortcuts and snap areas
# _ 236
# Animate elements as they scroll into view.
# _ 237
# Simple, unobtrusive authentication for Node.js.
# _ 238
# Let us control diffusion models!
# _ 240
# :ok_hand: Drag and drop so simple it hurts
# _ 241
# A lightweight, customizable Vue UI library for mobile web apps.
# _ 242
# TDengine is an open source, high-performance, cloud native time-series database optimized for Internet of Things (IoT), Connected Cars, Industrial IoT and DevOps.
# _ 244
# A Foundation for Scalable Cross-Platform Apps
# _ 245
# Apache Flink
# _ 246
# Bitmap & tilemap generation from a single example with the help of ideas from quantum mechanics
# _ 247
# Real-ESRGAN aims at developing Practical Algorithms for General Image/Video Restoration.
# _ 248
# Mastering Bitcoin 2nd Edition - Programming the Open Blockchain
# _ 249
# A spring that solves your animation problems.
# _ 250
# Dapr is a portable, event-driven, runtime for building distributed applications across cloud and edge.
# _ 252
#  Python examples of popular machine learning algorithms with interactive Jupyter demos and math being explained
# _ 253
# :trollface: A hex editor for WeChat/QQ/TIM - PC/QQ/TIM
# _ 254
# Elegant transition library for iOS & tvOS
# _ 255
# String validation
# _ 256
# The official mirror of the V8 Git repository
# _ 257
# HTTP load testing tool and library. It's over 9000!
# _ 259
# :octocat: Browser extension that simplifies the GitHub interface and adds useful features
# _ 260
# A lightweight, pure-Swift library for downloading and caching images from the web.
# _ 261
# Redisson - Easy Redis Java client with features of In-Memory Data Grid. Over 50 Redis based Java objects and services: Set, Multimap, SortedSet, Map, List, Queue, Deque, Semaphore, Lock, AtomicLong, Map Reduce, Publish / Subscribe, Bloom filter, Spring Cache, Tomcat, Scheduler, JCache API, Hibernate, MyBatis, RPC, local cache ...
# _ 263
#  Fast and simple video download library and CLI tool written in Go
# _ 264
# MiniGPT-4: Enhancing Vision-language Understanding with Advanced Large Language Models
# _ 265
# 30 Days of  React challenge is a step by step guide to learn React in 30 days.  These videos may help too: https://www.youtube.com/channel/UC7PNRuno1rzYPb1xLa4yktw
# _ 266
# Wiki.js | A modern and powerful wiki app built on Node.js
# _ 267
# 10 Weeks, 20 Lessons, Data Science for All!
# _ 268
# An open-source platform for making universal native apps with React. Expo runs on Android, iOS, and the web.
# _ 269
# A scalable, distributed, collaborative, document-graph database, for the realtime web
# _ 270
# sample code for several design patterns in PHP 8
# _ 271
#  Kubernetes CLI To Manage Your Clusters In Style!
# _ 272
# Pug – robust, elegant, feature rich template engine for Node.js
# _ 273
# The open-source notification infrastructure with fully functional embedded notification center
# _ 274
# Completely unstyled, fully accessible UI components, designed to integrate beautifully with Tailwind CSS.
# _ 275
# TCP port scanner, spews SYN packets asynchronously, scanning entire Internet in under 5 minutes.
# _ 276
# Complete container management platform
# _ 277
# Python
# _ 278
# JARVIS, a system to connect LLMs with ML community. Paper: https://arxiv.org/pdf/2303.17580.pdf
# _ 279
# Powerful yet simple to use screenshot software :desktop_computer: :camera_flash:
# _ 280
# JumpServer  4A
# _ 281
# Lens - The way the world runs Kubernetes
# _ 282
# Tornado is a Python web framework and asynchronous networking library, originally developed at FriendFeed.
# _ 283
# A runtime for writing reliable asynchronous applications with Rust. Provides I/O, networking, scheduling, timers, ...
# _ 284
# A powerful flow control component enabling reliability, resilience and monitoring for microservices. ()
# _ 286
#  Modern C++ Tutorial: C++11/14/17/20 On the Fly | https://changkun.de/modern-cpp/
# _ 287
# A tiny (130 bytes), secure, URL-friendly, unique string ID generator for JavaScript
# _ 289
# Jenkins automation server
# _ 290
#  Parse CSS and add vendor prefixes to rules by Can I Use
# _ 291
# Scheduling infrastructure for absolutely everyone.
# _ 292
# Modern JavaScript Tutorial
# _ 294
# a fast, scalable, multi-language and extensible build system
# _ 295
# Normalizes nested JSON according to a schema
# _ 297
# :rocket:A simple & beautiful tool for pictures uploading built by vue-cli-electron-builder
# _ 298
# A web framework for Rust.
# _ 299
# Babylon.js is a powerful, beautiful, simple, and open game and rendering engine packed into a friendly JavaScript framework.
# _ 301
# qBittorrent BitTorrent client
# _ 302
# Your ultimate Go microservices framework for the cloud-native era.
# _ 304
# /
# _ 305
# A cloud-native vector database, storage for next generation AI applications
# _ 306
# binary releases of VS Code without MS branding/telemetry/licensing
# _ 309
# Mac//(A plugin for Mac WeChat)
# _ 310
# Most commonly used git tips and tricks.
# _ 311
# Cross-platform React UI packages
# _ 312
#  Apple  Swift The Swift Programming Language
# _ 313
# A modern load testing tool, using Go and JavaScript - https://k6.io
# _ 314
# An extensible media player for Android
# _ 315
# A simple, lightweight JavaScript API for handling browser cookies
# _ 316
# Free Bootstrap 4 Admin Dashboard Template
# _ 317
# Spacedrive is an open source cross-platform file explorer, powered by a virtual distributed filesystem written in Rust.
# _ 318
# ECMAScript 6 JavaScript  ECMAScript 6
# _ 319
# REST API for any Postgres database
# _ 320
# A logger for just about everything.
# _ 321
# Delve is a debugger for the Go programming language.
# _ 322
# For empowering community
# _ 324
# Cross platform GUI toolkit in Go inspired by Material Design
# _ 325
# FlatBuffers: Memory Efficient Serialization Library
# _ 326
# Port of OpenAI's Whisper model in C/C++
# _ 327
# JHipster is a development platform to quickly generate, develop, & deploy modern web applications & microservice architectures.
# _ 328
# Dead simple Object schema validation
# _ 329
# -Chrome, Chrome, Chrome~  ChromePluginHeroes, Write a Chinese manual for the excellent Chrome plugin, let the Chrome plugin heroes benefit the human~ 01
# _ 330
# Compatibility tool for Steam Play based on Wine and additional components
# _ 331
# A Go microservices framework
# _ 332
# Fast, secure, efficient backup program
# _ 333
# Redefined chart library built with React and D3
# _ 334
# Apple TV Aerial Screensaver for Mac
# _ 335
# A set of examples around pytorch in Vision, Text, Reinforcement Learning, etc.
# _ 336
# Switch hosts quickly!
# _ 337
# PArallel Distributed Deep LEarning: Machine Learning Framework from Industrial Practice &
# _ 338
#
# _ 339
# Lenster is a decentralized and permissionless social media app built with Lens Protocol
# _ 341
# The Ruby Programming Language
# _ 342
# An HTML5 saveAs() FileSaver implementation
# _ 343
# Zstandard - Fast real-time compression algorithm
# _ 344
# In-browser Markdown editor
# _ 345
#  ScreenToGif allows you to record a selected area of your screen, edit and save it as a gif or video.
# _ 346
#   OpenAPI/Swagger-generated API Reference Documentation
# _ 347
# Lightweight, Portable, Flexible Distributed/Mobile Deep Learning with Dynamic, Mutation-aware Dataflow Dep Scheduler; for Python, R, Julia, Scala, Go, Javascript and more
# _ 348
#  A Vue.js 3 UI Library made by Element team
# _ 349
# Python programs, usually short, of considerable difficulty, to perfect particular skills.
# _ 350
# WinGet is the Windows Package Manager. This project includes a CLI (Command Line Interface), PowerShell modules, and a COM (Component Object Model) API (Application Programming Interface).
# _ 351
#  Terminal string styling done right
# _ 352
# SQL powered operating system instrumentation, monitoring, and analytics.
# _ 353
# Solidity, the Smart Contract Programming Language
# _ 354
# Sends your logs to files, sockets, inboxes, databases and various web services
# _ 355
#  Vue.js  Vue.js
# _ 356
# Node.js test runner that lets you develop with confidence
# _ 357
# An open source trusted cloud native registry project that stores, signs, and scans content.
# _ 358
# The hacker's browser.
# _ 359
# A simple, fast, and fun package for building command line apps in Go
# _ 360
# How to Make a Computer Operating System in C++
# _ 361
# Concise, consistent, and legible badges in SVG and raster format
# _ 362
# A fully featured React components library
# _ 363
# :bird: :zap: Bluebird is a full featured promise library with unmatched performance.
# _ 364
# Parse Server for Node.js / Express
# _ 365
# Examples of how to do query, style, dom, ajax, event etc like jQuery with plain javascript.
# _ 366
# A modern replacement for Redis and Memcached
# _ 367
# Guide to securing and improving privacy on macOS
# _ 368
# A modified web browser that helps in responsive web development. A web developer's must have dev-tool.
# _ 371
# Image-to-Image Translation in PyTorch
# _ 372
#
# _ 373
# LabelImg is now part of the Label Studio community. The popular image annotation tool created by Tzutalin is no longer actively being developed, but you can check out Label Studio, the open source data labeling tool for images, text, hypertext, audio, video and time-series data.
# _ 374
# An open source iOS framework for GPU-based image and video processing
# _ 375
# The most powerful data validation library for JS
# _ 376
#  A CLI workflow for the administration of macOS applications distributed as binaries
# _ 377
# A toolkit with common assertions and mocks that plays nicely with the standard library
# _ 378
# Simple to use, blazing fast and thoroughly tested WebSocket client and server for Node.js
# _ 379
# Jitsi Meet - Secure, Simple and Scalable Video Conferences that you use as a standalone app or embed in your web application.
# _ 380
#  Web File Browser
# _ 382
# JavaScript Testing utilities for React
# _ 383
# 100-Days-Of-ML-Code
# _ 384
# Cocoa framework and Obj-C dynamism bindings for ReactiveSwift.
# _ 386
#  Step-by-step tutorial to build a modern JavaScript stack.
# _ 387
# A community-driven modular vim/neovim distribution - The ultimate vimrc
# _ 388
# The headless editor framework for web artisans.
# _ 389
# A React-based UI toolkit for the web
# _ 390
# Alternative firmware for ESP8266 and ESP32 based devices with easy configuration using webUI, OTA updates, automation using timers or rules, expandability and entirely local control over MQTT, HTTP, Serial or KNX. Full documentation at
# _ 391
# eladmin jpa  Spring Boot 2.6.4 Jpa Spring SecurityRedisVue  RBAC
# _ 392
# Textual is a Rapid Application Development framework for Python.  Build sophisticated user interfaces with a simple Python API. Run your apps in the terminal and (coming soon) a web browser!
# _ 393
# Elegant Scraper and Crawler Framework for Golang
# _ 394
# A cross-platform command-line utility that creates projects from cookiecutters (project templates), e.g. Python package projects, C projects.
# _ 395
# NES-style CSS Framework | CSS
# _ 397
# Learn Go with test-driven development
# _ 398
# RxJava bindings for Android
# _ 399
# Fast HTTP package for Go. Tuned for high performance. Zero memory allocations in hot paths. Up to 10x faster than net/http
# _ 401
# The fastest knowledge base for growing teams. Beautiful, realtime collaborative, feature packed, and markdown compatible.
# _ 403
# Tool for visualizing GitHub profiles
# _ 404
# A cross-platform GUI library for Rust, inspired by Elm
# _ 405
# An extensible iOS and OS X animation library, useful for physics-based interactions.
# _ 406
# A modern editor with a backend written in Rust.
# _ 407
# Simple to use local JSON database. Use native JavaScript API to query. Written in TypeScript. (supports Node, Electron and the browser)
# _ 408
# Low-code platform for building business applications. Connect to databases, cloud storages, GraphQL, API endpoints, Airtable, Google sheets, OpenAI, etc and build apps using drag and drop application builder. Built using JavaScript/TypeScript.
# _ 409
# Virtual machines for iOS and macOS
# _ 410
# Latex code for making neural networks diagrams
# _ 411
# Peace of mind from prototype to production
# _ 412
# Manage and switch between multiple proxies quickly & easily.
# _ 413
# The classic email sending library for PHP
# _ 414
# Materials and IPython notebooks for "Python for Data Analysis" by Wes McKinney, published by O'Reilly Media
# _ 415
# A game theoretic approach to explain the output of any machine learning model.
# _ 416
# ESM-powered frontend build tool. Instant, lightweight, unbundled development.
# _ 417
#  A beautiful, fluid, and extensible dialogs API for Kotlin & Android.
# _ 418
# A reference implementation of GraphQL for JavaScript
# _ 420
# Notepad++ official repository
# _ 422
# The Reactive Extensions for JavaScript
# _ 423
# p5.js is a client-side JS platform that empowers artists, designers, students, and anyone to learn to code and express themselves creatively on the web. It is based on the core principles of Processing. http://twitter.com/p5xjs —
# _ 424
#
# _ 425
# Code for the paper "Language Models are Unsupervised Multitask Learners"
# _ 426
# :page_facing_up: Awesome CV is LaTeX template for your outstanding job application
# _ 427
# ///////Google/Facebook/Amazon/eBayPR
# _ 428
# Mobile-first, accessible components for React Native & Web to build consistent UI across Android, iOS and Web.
# _ 429
# Like Prometheus, but for logs.
# _ 430
# :books: The definitive guide to TypeScript and possibly the best TypeScript book :book:. Free and Open Source
# _ 431
# A full-stack framework for Laravel that takes the pain out of building dynamic UIs.
# _ 432
# Apache RocketMQ is a cloud native messaging and streaming platform, making it simple to build event-driven applications.
# _ 433
# Simple animation libraries for delightful user interfaces
# _ 435
#  A list of awesome Linux softwares
# _ 436
# Create UIs for your machine learning model in Python in 3 minutes
# _ 437
# Drag and Drop for React
# _ 438
# A high-level browser automation library.
# _ 439
# Native GraphQL Database with graph backend
# _ 440
# A Swift Autolayout DSL for iOS & OS X
# _ 441
#
# _ 442
#  Node.js tool for optimizing SVG files
# _ 443
# A fast, offline-first, reactive Database for JavaScript Applications https://rxdb.info/
# _ 444
# A terminal emulator for the 21st century.
# _ 445
#  V2Ray  &
# _ 446
# Personal CRM. Remember everything about your friends, family and business relationships.
# _ 448
# Open source, production-ready animation and gesture library for React
# _ 449
# A fast, well-tested and widely used WebSocket implementation for Go.
# _ 450
# Browser fingerprinting library. Compared to Fingerprint Pro has limited accuracy (40 - 60%).
# _ 451
#   A simple, scalable, and powerful architecture for building production ready React applications.
# _ 452
# Cross-platform, fast, feature-rich, GPU based terminal
# _ 453
# FizzBuzz Enterprise Edition is a no-nonsense implementation of FizzBuzz made by serious businessmen for serious business purposes.
# _ 454
# There can be more than Notion and Miro. AFFiNE is a next-gen knowledge base that brings planning, sorting and creating all together. Privacy first, open-source, customizable and ready to use.
# _ 455
# A collection of loading indicators animated with CSS
# _ 456
# The PHP Unit Testing framework.
# _ 457
# A new markup-based typesetting system that is powerful and easy to learn.
# _ 458
# .NET MAUI is the .NET Multi-platform App UI, a framework for building native device applications spanning mobile, tablet, and desktop.
# _ 459
# Implementation of Reinforcement Learning Algorithms. Python, OpenAI Gym, Tensorflow. Exercises and Solutions to accompany Sutton's Book and David Silver's course.
# _ 460
# Python sample codes for robotics algorithms.
# _ 461
# C++ Library Manager for Windows, Linux, and MacOS
# _ 462
# A simulation data generator
# _ 463
# Monospaced font family for user interface and coding environments
# _ 465
# Make images smaller using best-in-class codecs, right in the browser.
# _ 466
# Blazing fast, structured, leveled logging in Go.
# _ 467
# Fast C++ logging library.
# _ 468
# Home repository for .NET Core
# _ 469
#  The official router for Vue 2
# _ 470
# A good looking terminal emulator which mimics the old cathode display...
# _ 471
# Vue drag-and-drop component based on Sortable.js
# _ 472
#  A programming language for the ancient Chinese.
# _ 474
# A JavaScript implementation of various web standards, for use with Node.js
# _ 475
# 1kB-ish JavaScript framework for building hypertext applications
# _ 476
# Data Apps & Dashboards for Python. No JavaScript Required.
# _ 477
# Selector library for Redux
# _ 478
# A set of free MIT-licensed high-quality SVG icons for UI development.
# _ 479
# Recoil is an experimental state management library for React apps. It provides several capabilities that are difficult to achieve with React alone, while being compatible with the newest features of React.
# _ 480
# Skeleton: A Dead Simple, Responsive Boilerplate for Mobile-Friendly Development
# _ 481
# Learn OpenCV  : C++ and Python Examples
# _ 482
# :rocket:  A fully-featured, production ready caching GraphQL client for every UI framework and GraphQL server.
# _ 483
# A powerful little TUI framework
# _ 484
# GraalVM: Run Programs Faster Anywhere :rocket:
# _ 486
# The fastai book, published as Jupyter Notebooks
# _ 487
# IJKplayerExoPlayerMediaPlayerHTTPSgifrotation90,270 rtspconcatmpeg
# _ 488
# A curated list of awesome things related to HarmonyOS.
# _ 489
# Polyfill to remove click delays on browsers with touch UIs
# _ 490
# Ready-to-use OCR with 80+ supported languages and all popular writing scripts including Latin, Chinese, Arabic, Devanagari, Cyrillic and etc.
# _ 491
#  Build multimodal AI services via cloud native technologies
# _ 492
# Saleor Core: the high performance, composable, headless commerce API.
# _ 494
# [Example APPS] Basic Flutter apps, for flutter devs.
# _ 495
# The Open Source kanban (built with Meteor). Keep variable/table/field names camelCase. For translations, only add Pull Request changes to wekan/i18n/en.i18n.json , other translations are done at https://app.transifex.com/wekan/ only.
# _ 496
# The ChatGPT Retrieval Plugin lets you easily find personal or work documents by asking questions in natural language.
# _ 497
# MyBatis SQL mapper framework for Java
# _ 498
# An official read-only mirror of http://hg.nginx.org/nginx/ which is updated hourly. Pull requests on GitHub cannot be accepted and will be automatically closed. The proper way to submit changes to nginx is via the nginx development mailing list, see http://nginx.org/en/docs/contributing_changes.html
# _ 499
# Building blocks for digital commerce
# _ 501
# Low code platform for creating internal tools, workflows, and admin panels in minutes. Supports PostgreSQL, MySQL, MSSQL, MongoDB, Rest API, Docker, K8s, and more . Budibase, the low code platform you'll enjoy using
# _ 502
# Kuboard  Kubernetes  Kubernetes  Kubernetes v1.23.4 (k8s install)
# _ 503
# A curated list of amazingly awesome open-source sysadmin resources.
# _ 504
# CodeEdit App for macOS – Elevate your code editing experience. Open source, free forever.
# _ 505
# :books: GoCGOGoRPCProtobufWeb()
# _ 506
# The Crystal Programming Language
# _ 507
# Your window into the Elastic Stack
# _ 508
#  Born to build better enterprise frameworks and apps with Node.js & Koa
# _ 509
# a vue2.0 minimal admin template
# _ 510
# A tree explorer plugin for vim.
# _ 511
# Ecosystem to transform any database into a distributed database system, and enhance it with sharding, elastic scaling, encryption features & more
# _ 512
# Stand-alone parallax scrolling library for mobile (Android + iOS) and desktop. No jQuery. Just plain JavaScript (and some love).
# _ 513
# Magenta: Music and Art Generation with Machine Intelligence
# _ 514
# Develop Desktop, Embedded, Mobile and WebAssembly apps with C# and XAML. The most popular .NET Foundation community project.
# _ 515
# Implementation of ImageView for Android that supports zooming, by various touch gestures.
# _ 516
# A powerful image downloading and caching library for Android
# _ 517
# A modern vue admin. It is based on Vue3, vite and TypeScript. It's fast
# _ 519
# Official home of the DB Browser for SQLite (DB4S) project. Previously known as "SQLite Database Browser" and "Database Browser for SQLite". Website at:
# _ 520
# pytorch handbookPyTorchPytorch
# _ 522
# Web Starter Kit - a workflow for multi-device websites
# _ 523
# The best way to start a full-stack, typesafe Next.js app
# _ 525
# :rocket::star: Minimalistic, powerful and extremely customizable Zsh prompt
# _ 526
# The Go language implementation of gRPC. HTTP/2 based RPC
# _ 527
# Podman: A tool for managing OCI containers and pods.
# _ 528
#  HikariCPA solid, high-performance, JDBC connection pool at last.
# _ 529
# LlamaIndex (GPT Index) is a data framework for your LLM applications
# _ 530
# Fast multi-threaded, hybrid-out-of-core query engine focussing on DataFrame front-ends
# _ 531
#  (Self-hosted file management and sharing system, supports multiple storage providers)
# _ 532
# Create graphics with a hand-drawn, sketchy, appearance
# _ 533
# Interactive deep learning book with multi-framework code, math, and discussions. Adopted at 400 universities from 60 countries including Stanford, MIT, Harvard, and Cambridge.
# _ 534
#   A command-line system information tool written in bash 3.2+
# _ 535
#  Fast, lightweight & schema-less search backend. An alternative to Elasticsearch that runs on a few MBs of RAM.
# _ 537
# Torch implementation of neural style algorithm
# _ 538
# The automation tower defense RTS
# _ 539
#   An enterprise-class UI components based on Ant Design and Vue.
# _ 540
# CSS is powerful, you can do a lot of things without JS.
# _ 541
# This is the Rust course used by the Android team at Google. It provides you the material to quickly teach Rust to everyone.
# _ 542
# UNIX-like reverse engineering framework and command-line toolset
# _ 543
# PythonIP(proxy pool)
# _ 544
# A powerful HTTP router and URL matcher for building Go web servers with
# _ 545
# Roadmap to becoming a React developer
# _ 546
# Instant-loading web apps, without effort
# _ 548
# Open Source PHP Framework (originally from EllisLab)
# _ 549
# A collection of common interactive command line user interfaces.
# _ 550
# Free and Open source Web Builder Framework. Next generation tool for building templates without coding
# _ 551
# Eclipse Theia is a cloud & desktop IDE framework implemented in TypeScript.
# _ 552
# :package::rocket: Fully automated version management and package publishing
# _ 553
# litemall = Spring Boot + Vue +  + Vue
# _ 555
# A command-line installer for Windows.
# _ 556
# A framework for building Mobile cross-platform UI
# _ 557
# .NET Decompiler with support for PDB generation, ReadyToRun, Metadata (&more) - cross-platform!
# _ 558
# :honeybee: A collection of awesome .NET core libraries, tools, frameworks and software
# _ 559
# Smart, Fast and Extensible Build System
# _ 560
# Zulip server and web application. Open-source team chat that helps teams stay productive and focused.
# _ 561
# Blazing fast Neovim config providing solid defaults and a beautiful UI, enhancing your neovim experience.
# _ 562
#
# _ 563
# Default configuration for Le Wagon's students
# _ 564
# Mastering Ethereum, by Andreas M. Antonopoulos, Gavin Wood
# _ 565
# Harness the power of AutoLayout NSLayoutConstraints with a simplified, chainable and expressive syntax. Supports iOS and OSX Auto Layout
# _ 566
# The motion graphics toolbelt for the web
# _ 567
# JavaScript data grid with a spreadsheet look & feel. Works with React, Angular, and Vue. Supported by the Handsontable team
# _ 568
# Graph Neural Network Library for PyTorch
# _ 570
# completely free for everyone. Its build-in Flutter Dart.
# _ 571
# Find vulnerabilities, misconfigurations, secrets, SBOM in containers, Kubernetes, code repositories, clouds and more
# _ 572
#  Simple and complete React DOM testing utilities that encourage good testing practices.
# _ 573
# Flexbox for Android
# _ 574
# Actix Web is a powerful, pragmatic, and extremely fast web framework for Rust.
# _ 576
# x86 virtualization in your browser, recompiling x86 to wasm on the fly
# _ 577
# A draggable and resizable grid layout with responsive breakpoints, for React.
# _ 578
# ZeroNet - Decentralized websites using Bitcoin crypto and BitTorrent network
# _ 579
# A lightweight and modular front-end framework for developing fast and powerful web interfaces
# _ 580
# Liberating Web Analytics. Star us on Github? +1. Matomo is the leading open alternative to Google Analytics that gives you full control over your data. Matomo lets you easily collect data from websites & apps and visualise this data and extract insights. Privacy is built-in. We love Pull Requests!
# _ 581
# CAT  Java, C/C++, Node.js, Python, Go MVCRPC
# _ 582
#  Coroutine-based concurrency library for PHP
# _ 583
# CNCF Jaeger, a Distributed Tracing Platform
# _ 584
# Extendable version manager with support for Ruby, Node.js, Elixir, Erlang & more
# _ 585
# MagicMirror² is an open source modular smart mirror platform. With a growing list of installable modules, the MagicMirror² allows you to convert your hallway or bathroom mirror into your personal assistant.
# _ 586
# A pure node.js JavaScript Client implementing the MySQL protocol.
# _ 587
# Share your terminal as a web application
# _ 588
# A syntax-highlighting pager for git, diff, and grep output
# _ 589
# Format input text content when you are typing...
# _ 590
# An unidentifiable mechanism that helps you bypass GFW.
# _ 591
# Relay is a JavaScript framework for building data-driven React applications.
# _ 592
#    RuoYi-Vue  Pro  Spring Boot + MyBatis Plus + Vue & Element  +  RBAC SaaS Flowable   Star
# _ 595
# Focus on what matters instead of fighting with Git.
# _ 596
# fugitive.vim: A Git wrapper so awesome, it should be illegal
# _ 597
# SeaweedFS is a fast distributed storage system for blobs, objects, files, and data lake, for billions of files! Blob store has O(1) disk seek, cloud tiering. Filer supports Cloud Drive, cross-DC active-active replication, Kubernetes, POSIX FUSE mount, S3 API, S3 Gateway, Hadoop, WebDAV, encryption, Erasure Coding.
# _ 598
# Node version management
# _ 599
# Designing Data-Intensive ApplicationDDIA
# _ 601
# Network-wide ads & trackers blocking DNS server
# _ 602
# A virtual machine for executing programs written in Hack.
# _ 603
# Interactive Data Visualization in the browser, from  Python
# _ 604
# A query builder for PostgreSQL, MySQL, CockroachDB, SQL Server, SQLite3 and Oracle, designed to be flexible, portable, and fun to use.
# _ 605
# Turn (almost) any Python command line program into a full GUI application with one line
# _ 606
# A rich text editor for everyday writing
# _ 607
# WordPress, Git-ified. This repository is just a mirror of the WordPress subversion repository. Please do not send pull requests. Submit pull requests to https://github.com/WordPress/wordpress-develop and patches to https://core.trac.wordpress.org/ instead.
# _ 608
# Ethereum JavaScript API
# _ 609
# World's fastest and most advanced password recovery utility
# _ 610
# The swiss army knife of lossless video/audio editing
# _ 611
# matplotlib: plotting with Python
# _ 612
#
# _ 613
# Thunk middleware for Redux
# _ 614
# Mobile UI Components based on Vue & WeUI
# _ 615
# vite+vue3+ginTS,JSjwt,chatGPT
# _ 616
#  ice.js: The Progressive App Framework Based On React React
# _ 617
# The Roslyn .NET compiler provides C# and Visual Basic languages with rich code analysis APIs.
# _ 618
# BCC - Tools for BPF-based Linux IO analysis, networking, monitoring, and more
# _ 619
# A WebGL accelerated JavaScript library for training and deploying ML models.
# _ 620
# GoReplay is an open-source tool for capturing and replaying live HTTP traffic into a test environment in order to continuously test your system with real data. It can be used to increase confidence in code deployments, configuration changes and infrastructure changes.
# _ 621
# (BlockChain)FabricEthereum
# _ 622
# Redis Go client
# _ 623
# A tool to enforce Swift style and conventions.
# _ 624
#  1000+ Hand-Crafted Go Examples, Exercises, and Quizzes.  Learn Go by fixing 1000+ tiny programs.
# _ 625
# Authentication for the Web.
# _ 626
# ncnn is a high-performance neural network inference framework optimized for the mobile platform
# _ 627
# ChatGPTPandora, a ChatGPT that helps you breathe smoothly.
# _ 629
# A little tool to play with Windows security
# _ 630
#  Frontend Knowledge Structure
# _ 631
# Dropzone is an easy to use drag'n'drop library. It supports image previews and shows nice progress bars.
# _ 633
# Application Architecture for Building User Interfaces
# _ 634
#  visx | visualization components
# _ 635
# Microsoft Cognitive Toolkit (CNTK), an open source deep-learning toolkit
# _ 636
# Loads environment variables from .env for nodejs projects.
# _ 637
# Spring Cloud
# _ 638
# Full featured HTML framework for building iOS & Android apps
# _ 639
# A brief computer graphics / rendering course
# _ 640
# lean & mean status/tabline for vim that's light as air
# _ 641
# You like pytorch? You like micrograd? You love tinygrad!
# _ 642
# OpenVPN road warrior installer for Ubuntu, Debian, AlmaLinux, Rocky Linux, CentOS and Fedora
# _ 643
# An open source cybersecurity protocol for syncing decentralized graph data.
# _ 644
# Minimal templating on steroids.
# _ 645
# A modern formatting library
# _ 646
# Fish shell like syntax highlighting for Zsh.
# _ 647
# Cocos2d-x is a suite of open-source, cross-platform, game-development tools utilized by millions of developers across the globe. Its core has evolved to serve as the foundation for Cocos Creator 1.x & 2.x.
# _ 648
# Accelerated JavaScript animation.
# _ 649
# Automated nginx proxy for Docker containers using docker-gen
# _ 650
# The original sources of MS-DOS 1.25 and 2.0, for reference purposes
# _ 651
#  ChatGPT API     -    Browser extension and cross-platform desktop application for translation based on ChatGPT API.
# _ 652
# A tiling window manager for macOS based on binary space partitioning
# _ 654
# MindsDB is a Server for Artificial Intelligence Logic. Enabling developers to ship to production AI powered projects (from the latest LLMs, vector operations, state of the art time-series forecasting to Machine Learning) in a fast and scalable way.
# _ 655
# This repository is outdated and new Boost Note app is available! We've launched a new Boost Note app which supports real-time collaborative writing. https://github.com/BoostIO/BoostNote-App
# _ 656
#  Accelerate your web app development  | Build fast. Run fast.
# _ 657
# Vue3 + Element Plus
# _ 659
# Spring Boot 2.XSpring CloudSpring Cloud AlibabaDubbo Star 1024
# _ 661
# Daemon for easy but powerful stats aggregation
# _ 662
# sketch + style = paints :art: (TOG2018/SIGGRAPH2018ASIA)
# _ 663
# A gradio web UI for running Large Language Models like LLaMA, llama.cpp, GPT-J, Pythia, OPT, and GALACTICA.
# _ 664
# Parsing gigabytes of JSON per second
# _ 665
# Revive unavailable songs for Netease Cloud Music
# _ 666
# LeetCode Problems' Solutions
# _ 667
# A cheatsheet of modern C++ language and library features.
# _ 669
# A document head manager for React
# _ 670
# Plugins for Flutter maintained by the Flutter team
# _ 671
# An Android library for managing images and the memory they use.
# _ 672
# Dark Reader Chrome and Firefox extension
# _ 673
# Premium hand-crafted icons built by Ionic, for Ionic apps and web apps everywhere
# _ 674
# Less. The dynamic stylesheet language.
# _ 676
# High performance and SEO friendly lazy loader for images (responsive and normal), iframes and more, that detects any visibility changes triggered through user interaction, CSS or JavaScript without configuration.
# _ 677
# Low-code programming for event-driven applications
# _ 678
# List of JavaScript methods which you can use natively + ESLint Plugin
# _ 680
# The JavaScript Drag & Drop library your grandparents warned you about.
# _ 681
#  UI
# _ 682
# Jupyter notebooks for the code samples of the book "Deep Learning with Python"
# _ 683
# OpenAPI Generator allows generation of API client libraries (SDK generation), server stubs, documentation and configuration automatically given an OpenAPI Spec (v2, v3)
# _ 684
# A gardening app illustrating Android development best practices with migrating a View-based app to Jetpack Compose.
# _ 686
# macOS system monitor in your menu bar
# _ 687
# Slim(toolkit): Don't change anything in your container image and minify it by up to 30x (and for compiled languages even more) making it secure too! (free and open source)
# _ 689
# An Emacs framework for the stubborn martian hacker
# _ 690
# Turn any program that uses STDIN/STDOUT into a WebSocket server. Like inetd, but for WebSockets.
# _ 691
#  SST makes it easy to build full-stack serverless apps.
# _ 692
# Script to remove Windows 10 bloatware.
# _ 693
# Modular and customizable Material Design UI components for the web
# _ 694
# MicroPython - a lean and efficient Python implementation for microcontrollers and constrained systems
# _ 696
# Google Chromium, sans integration with Google
# _ 697
# Tinker is a hot-fix solution library for Android, it supports dex, library and resources update without reinstall apk.
# _ 698
# Mars is a cross-platform network component  developed by WeChat.
# ...
# _ 2476
# A file list program that supports multiple storages, powered by Gin and Solidjs. /  Gin  Solidjs
# _ 2477
# OpenPose: Real-time multi-person keypoint detection library for body, face, hands, and foot estimation
# _ 2478
# Automatic SQL injection and database takeover tool
# _ 2479
# Set up a personal VPN in the cloud
# _ 2481
# A completely customizable framework for building rich text editors. (Currently in beta.)
# _ 2482
# CockroachDB - the open source, cloud-native distributed SQL database.
# _ 2483
# The lazier way to manage everything docker
# _ 2484
# A lightweight JavaScript library for creating particles
# _ 2485
# Windows Calculator: A simple yet powerful calculator that ships with Windows
# _ 2486
# Presentation Slides for Developers
# _ 2487
# React Hooks for Data Fetching
# _ 2488
#  Express inspired web framework written in Go
# _ 2491
# Reorderable drag-and-drop lists for modern browsers and touch devices. No jQuery or framework required.
# _ 2492
# The next open source file uploader for web browsers :dog:
# _ 2493
#  59 Implementations/tutorials of deep learning papers with side-by-side notes ; including transformers (original, xl, switch, feedback, vit, ...), optimizers (adam, adabelief, ...), gans(cyclegan, stylegan2, ...),  reinforcement learning (ppo, dqn), capsnet, distillation, ...
# _ 2495
# Drone is a Container-Native, Continuous Delivery Platform
# _ 2496
# DataWorks(https://help.aliyun.com/document_detail/137663.html)
# _ 2498
# Algorithms and Data Structures implemented in JavaScript for beginners, following best practices.
# _ 2499
# JavaScript's utility _ belt
# _ 2500
#  Java Core Sprout : basic, concurrent, algorithm
# _ 2501
# A browser automation framework and ecosystem.
# _ 2502
#   Move Fast and Break Nothing. End-to-end typesafe APIs made easy.
# _ 2503
#
# _ 2505
# an easy-to-use dynamic service discovery, configuration and service management platform for building cloud native applications.
# _ 2506
# PyTorch Tutorial for Deep Learning Researchers
# _ 2507
# A UI library by WeChat official design team, includes the most useful widgets/modules in mobile web applications.
# _ 2508
# Run Kubernetes locally
# _ 2509
# Client-side JavaScript PDF generation for everyone.
# _ 2510
# Beautiful charts for iOS/tvOS/OSX! The Apple side of the crossplatform MPAndroidChart.
# _ 2511
# Facebook AI Research Sequence-to-Sequence Toolkit written in Python.
# _ 2512
# The OpenAPI Specification Repository
# _ 2513
# Faker is a PHP library that generates fake data for you
# _ 2514
# Automated auditing, performance metrics, and best practices for the web.
# _ 2515
# AI-Powered Photos App for the Decentralized Web
# _ 2516
# DeepSpeed is a deep learning optimization library that makes distributed training and inference easy, efficient, and effective.
# _ 2517
# Consul is a distributed, highly available, and data center aware solution to connect and configure applications across dynamic, distributed infrastructure.
# _ 2518
# 2017Sharing the knowledge of buy an own house that according  to the experience at hangzhou in 2017 to all the people. It's not easy to buy a own house, so I hope that it would be useful to everyone.
# _ 2519
# Reverse engineered ChatGPT API
# _ 2520
# Fish-like autosuggestions for zsh
# _ 2521
# has no description
# _ 2522
# A set of tools that keep Java sweet.
# _ 2523
# The fast, flexible, and elegant library for parsing and manipulating HTML and XML.
# _ 2524
#  Industrial-strength Natural Language Processing (NLP) in Python
# _ 2525
# Simple, scalable state management.
# _ 2526
# PythonWebPython
# _ 2527
# High-Resolution Image Synthesis with Latent Diffusion Models
# _ 2528
# Python best practices guidebook, written for humans.
# _ 2529
# Ray is a unified framework for scaling AI and Python applications. Ray consists of a core distributed runtime and a toolkit of libraries (Ray AIR) for accelerating ML workloads.
# _ 2530
# Lean's LEDE source
# _ 2531
# Image Super-Resolution for Anime-Style Art
# _ 2532
# The Select Component for React.js
# _ 2533
# tcpudpsocks5httpsshdnssocks5……weba lightweight, high-performance, powerful intranet penetration proxy server, with a powerful web management terminal.
# _ 2534
#  Hacker Eric S. Raymond
# _ 2535
# YApi QA
# _ 2537
# Git extensions to provide high-level repository operations for Vincent Driessen's branching model.
# _ 2538
# The open-source database for the realtime web.
# _ 2539
# CLI tool for Angular
# _ 2540
# A faster, better and more stable redis desktop manager [GUI client], compatible with Linux, Windows, Mac. What's more, it won't crash when loading massive keys.
# _ 2541
# Lightning-fast and Powerful Code Editor written in Rust
# _ 2542
# SpringBoot+Vue
# _ 2543
# High performance, minimalist Go web framework
# _ 2544
# Roadmap to becoming an Artificial Intelligence Expert in 2022
# _ 2545
# In-browser code editor (version 5, legacy)
# _ 2546
# Unofficial Bitwarden compatible server written in Rust, formerly known as bitwarden_rs
# _ 2547
#  MySQL binlog &
# _ 2548
#  A spring physics based React animation library
# _ 2549
# Spring Cloud Alibaba provides a one-stop solution for application development for the distributed solutions of Alibaba middleware.
# _ 2550
# Making Docker and Kubernetes management easy.
# _ 2551
# A JavaScript library to position floating elements and create interactions for them.
# _ 2552
# PyTorch image models, scripts, pretrained weights -- ResNet, ResNeXT, EfficientNet, EfficientNetV2, NFNet, Vision Transformer, MixNet, MobileNet-V3/V2, RegNet, DPN, CSPNet, and more
# _ 2553
#  NGINX config generator on steroids
# _ 2554
# Flash OS images to SD cards & USB drives, safely and easily.
# _ 2556
# Web APIs for Django.
# _ 2557
# FAIR's research platform for object detection research, implementing popular algorithms like Mask R-CNN and RetinaNet.
# _ 2558
# MongoDB object modeling designed to work in an asynchronous environment.
# _ 2559
# Mattermost is an open source platform for secure collaboration across the entire software development lifecycle..
# _ 2560
# Spring BootSpring Boot & ShiroSpring BatchSpring CloudSpring Cloud AlibabaSpring Security & Spring Security OAuth2Springhttps://mrbird.cc
# _ 2561
# Streamlit — A faster way to build and share data apps.
# _ 2562
# Ace (Ajax.org Cloud9 Editor)
# _ 2563
# A window.fetch JavaScript polyfill.
# _ 2564
# Scalable datastore for metrics, events, and real-time analytics
# _ 2565
# aka "Bayesian Methods for Hackers": An introduction to Bayesian methods + probabilistic programming with a computation/understanding-first, mathematics-second point of view. All in pure Python ;)
# _ 2566
#  Modern documentation format and toolchain using Git and Markdown
# _ 2568
# Select2 is a jQuery based replacement for select boxes. It supports searching, remote data sets, and infinite scrolling of results.
# _ 2569
#  Simplified HTTP request client.
# _ 2570
# Python packaging and dependency management made easy
# _ 2571
# Code and documentation to train Stanford's Alpaca models, and generate the data.
# _ 2572
# Bind Android views and callbacks to fields and methods.
# _ 2573
# An open-source C++ library developed and used at Facebook.
# _ 2574
# High performance Node.js image processing, the fastest module to resize JPEG, PNG, WebP, AVIF and TIFF images. Uses the libvips library.
# _ 2575
# :snowman: Possibly the smallest compiler ever
# _ 2576
# A library that provides an embeddable, persistent key-value store for fast storage.
# _ 2578
# Create the next immutable state by mutating the current one
# _ 2579
# Full reference of LinkedIn answers 2023 for skill assessments (aws-lambda, rest-api, javascript, react, git, html, jquery, mongodb, java, Go, python, machine-learning, power-point) linkedin excel test lösungen, linkedin machine learning test LinkedIn test questions and answers
# _ 2581
# A rule-based tunnel for Android.
# _ 2582
# Modernizr is a JavaScript library that detects HTML5 and CSS3 features in the user’s browser.
# _ 2583
# A new type of shell
# _ 2585
# Detectron2 is a platform for object detection, segmentation and other visual recognition tasks.
# _ 2586
# For slim progress bars like on YouTube, Medium, etc
# _ 2587
# FASTJSON 2.0.x has been released, faster and more secure, recommend you upgrade.
# _ 2588
# The Serenity Operating System
# _ 2589
# Monitor for any changes in your node.js application and automatically restart the server - perfect for development
# _ 2590
# Command-line JSON processor
# _ 2591
# Mirror of Apache Kafka
# _ 2592
# Data science Python notebooks: Deep learning (TensorFlow, Theano, Caffe, Keras), scikit-learn, Kaggle, big data (Spark, Hadoop MapReduce, HDFS), matplotlib, pandas, NumPy, SciPy, Python essentials, AWS, and various command lines.
# _ 2593
# Vagrant is a tool for building and distributing development environments.
# _ 2594
# Javascript Canvas Library, SVG-to-Canvas (& canvas-to-SVG) Parser
# _ 2595
# How to create an OS from scratch
# _ 2596
# A Fast, Extensible Progress Bar for Python and CLI
# _ 2597
# A standard library for microservices.
# _ 2598
# 30 days of Python programming challenge is a step-by-step guide to learn the Python programming language in 30 days. This challenge may take more than100 days, follow your own pace.  These videos may help too: https://www.youtube.com/channel/UC7PNRuno1rzYPb1xLa4yktw
# _ 2599
# A series of Jupyter notebooks that walk you through the fundamentals of Machine Learning and Deep Learning in Python using Scikit-Learn, Keras and TensorFlow 2.
# _ 2600
#  Express   Vue3  ChatGPT
# _ 2601
#  Everything is RSSible
# _ 2602
# React components for efficiently rendering large lists and tabular data
# _ 2603
# httphttp
# _ 2605
#  DEPRECATED – See https://github.com/ageron/handson-ml3 instead.
# _ 2606
# A code-searching tool similar to ack, but faster.
# _ 2607
# A list of semi to fully remote-friendly companies (jobs) in tech.
# _ 2608
# node.js command-line interfaces made easy
# _ 2609
#  Laws, Theories, Principles and Patterns that developers will find useful. #hackerlaws
# _ 2610
# Lovely console emulator package for Windows
# _ 2611
# A code-completion engine for Vim
# _ 2612
# Collection of various algorithms in mathematics, machine learning, computer science and physics implemented in C++ for educational purposes.
# _ 2613
# OpenMMLab Detection Toolbox and Benchmark
# _ 2614
# Python Fire is a library for automatically generating command line interfaces (CLIs) from absolutely any Python object.
# _ 2615
# A cloud-native Go microservices framework with cli tool for productivity.
# _ 2616
# Library for fast text representation and classification.
# _ 2617
# 30 Day Vanilla JS Challenge
# _ 2618
# To Be Top Javaer - Java
# _ 2619
# A docker-powered PaaS that helps you build and manage the lifecycle of applications
# _ 2620
# :love_letter: An extensible desktop mail app built on the modern web.  Forks welcome!
# _ 2621
# Patched fonts for Powerline users.
# _ 2622
# ShareX is a free and open source program that lets you capture or record any area of your screen and share it with a single press of a key. It also allows uploading images, text or other types of files to many supported destinations you can choose from.
# _ 2623
# A distributed task scheduling framework.XXL-JOB
# _ 2624
#  Assemble, configure, and deploy autonomous AI Agents in your browser.
# _ 2625
# A refreshingly simple data-driven game engine built in Rust
# _ 2628
#  Seamlessly visualize your JSON data instantly into graphs.
# _ 2629
# Asynchronous image downloader with cache support as a UIImageView category
# _ 2630
# Customizable admin dashboard template based on Angular 10+
# _ 2631
# The Kubernetes Package Manager
# _ 2632
# The most cited deep learning papers
# _ 2633
# A curated list of engineering blogs
# _ 2634
# An open platform for training, serving, and evaluating large language models. Release repo for Vicuna and FastChat-T5.
# _ 2635
# Fast, disk space efficient package manager
# _ 2637
# Open Source realtime backend in 1 file
# _ 2638
# Awesome Docker Compose samples
# _ 2639
# Event bus for Android and Java that simplifies communication between Activities, Fragments, Threads, Services, etc. Less code, better quality.
# _ 2640
# Inference code for LLaMA models
# _ 2642
# Convolutional Neural Networks
# _ 2643
# LinuxLinuxhttps://git.io/linux
# _ 2644
# Scalable, Portable and Distributed Gradient Boosting (GBDT, GBRT or GBM) Library,  for Python, R, Java, Scala, C++ and more. Runs on single machine, Hadoop, Spark, Dask, Flink and DataFlow
# _ 2645
#
# _ 2646
# A libre lightweight streaming front-end for Android.
# _ 2647
# RefreshLayoutOverScrollAndroidHeader Footer
# _ 2648
# A rugged, minimal framework for composing JavaScript behavior in your markup.
# _ 2649
# An iOS library to natively render After Effects vector animations
# _ 2650
# State machines and statecharts for the modern web.
# _ 2651
# Course Files for Complete Python 3 Bootcamp Course on Udemy
# _ 2652
# The fastai deep learning library
# _ 2653
# Swagger UI is a collection of HTML, JavaScript, and CSS assets that dynamically generate beautiful documentation from a Swagger-compliant API.
# _ 2654
# Recovers passwords from pixelized screenshots
# _ 2655
# The fastest HTTP/2 Go Web Framework. New, modern and easy to learn. Fast development with Code you control. Unbeatable cost-performance ratio :rocket:
# _ 2656
# The OWASP Cheat Sheet Series was created to provide a concise collection of high value information on specific application security topics.
# _ 2657
#  Windows / macOS / Linux :electron:
# _ 2658
# A complete and graceful API for Wechat.
# _ 2659
# The MongoDB Database
# _ 2660
# A high quality UI Toolkit built on Vue.js 2.0
# _ 2661
# Deep learning framework to train, deploy, and ship AI products Lightning fast.
# _ 2663
# Build Better Websites. Create modern, resilient user experiences with web fundamentals.
# _ 2664
# Emscripten: An LLVM-to-WebAssembly Compiler
# _ 2665
# A simple HTML5, YouTube and Vimeo player
# _ 2667
# The fundamental package for scientific computing with Python.
# _ 2668
#  Python Development Workflow for Humans.
# _ 2669
# :fire: Seata is an easy-to-use, high-performance, open source distributed transaction solution.
# _ 2670
# Cross-platform .NET sample microservices and container based application that runs on Linux Windows and macOS. Powered by .NET 7, Docker Containers and Azure Kubernetes Services. Supports Visual Studio, VS for Mac and CLI based environments with Docker CLI, dotnet CLI, VS Code or any other code editor.
# _ 2671
#  A magical documentation site generator.
# _ 2672
#  React for interactive command-line apps
# _ 2673
# Unified developer tools for JavaScript, TypeScript, and the web
# _ 2674
# Animate on scroll library
# _ 2675
# The Reliable USB Formatting Utility
# _ 2676
# Quasar Framework - Build high-performance VueJS user interfaces in record time
# _ 2677
# A private messenger for Android.
# _ 2678
# General-purpose programming language and toolchain for maintaining robust, optimal, and reusable software.
# _ 2679
#  Browser devtools extension for debugging Vue.js applications.
# _ 2680
# Cross-Platform React Native UI Toolkit
# _ 2681
# Experimental Nintendo Switch Emulator written in C#
# _ 2682
# Composable transformations of Python+NumPy programs: differentiate, vectorize, JIT to GPU/TPU, and more
# _ 2683
#  3+156000+HTML/CSS/JavaScript/Vue/React/Nodejs/TypeScript/ECMAScritpt/Webpack/Jquery//……
# _ 2684
# Next-generation ES module bundler
# _ 2685
# Simply beautiful open source icons
# _ 2686
# BRVAH:Powerful and flexible RecyclerAdapter
# _ 2687
# .NET debugger and assembly editor
# _ 2688
# A realtime distributed messaging platform
# _ 2689
# A javascript library for multi-touch gestures :// You can touch this
# _ 2690
# Component infrastructure and Material Design components for Angular
# _ 2691
# A collection of learning resources for curious software engineers
# _ 2692
# Vundle, the plug-in manager for Vim
# _ 2694
# Beautifully designed components built with Radix UI and Tailwind CSS.
# _ 2695
# Lightweight Kubernetes
# _ 2696
# Bootstrap 5 & Material Design UI KIT
# _ 2697
# A block-style editor with clean JSON output
# _ 2698
# Hystrix is a latency and fault tolerance library designed to isolate points of access to remote systems, services and 3rd party libraries, stop cascading failure and enable resilience in complex distributed systems where failure is inevitable.
# _ 2699
# A collaborative list of awesome Swift libraries and resources. Feel free to contribute!
# _ 2700
# Package your Node.js project into an executable
# _ 2701
# The Free Software Media System
# _ 2702

# %%
import mysql.connector

# Établir une connexion à la base de données MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="github"
)

# Créer un curseur pour exécuter des requêtes
cursor = conn.cursor()

# Requête SQL à exécuter
query = """
SELECT c.login AS Contributor, COUNT(rc.contributions) AS Contributions,
GROUP_CONCAT(r.Name) AS ContributedRepos FROM Contributor c JOIN RepoContributor rc
ON c.id = rc.contributor_id JOIN Repo r ON rc.repo_id = r.id GROUP BY c.login
ORDER BY COUNT(rc.contributions) DESC LIMIT 10;
"""

# Exécuter la requête SQL
cursor.execute(query)

# Récupérer les résultats de la requête
results = cursor.fetchall()

# Afficher les résultats
for row in results:
    contributor = row[0]
    contributions = row[1]
    contributed_repos = row[2]
    print(f"Contributor: {contributor}, Contributions: {contributions}, Contributed Repos: {contributed_repos} \n \n")

# Fermer le curseur et la connexion
cursor.close()
conn.close()
# Out:
# Contributor: dependabot[bot], Contributions: 681, Contributed Repos: blueprint,blurhash,bootstrap,bootstrap-datepicker,bootstrap-table,bootstrap-vue,bootswatch,bower,brain.js,brew,brook,browser-sync,browserslist,browsh,bubbletea,budibase,bull,caddy,caffeine,cal.com,carbon,card,cascadia-code,cat,chakra-ui,Chart.js,charts,ChatGPT-Next-Web,chatwoot,cheerio,Chinese-LLaMA-Alpaca,cilium,Ciphey,clap,classnames,CleanArchitecture,CleanArchitecture,cleave.js,cli,click,clipboard.js,Cloudreve,cobra,coc.nvim,darkreader,dash,dashboard,Data-Science-For-Beginners,dataease,dataloader,DataX,decap-cms,deep-learning-for-image-processing,DeepSpeed,delta,DeOldify,desktop,diagrams,diem,dio,directus,discourse,ant-design,apexcharts.js,apisix,apollo,apollo-client,appwrite,ar-cutpaste,ArchiveBox,argo-cd,argo-workflows,arthas,asciinema,asdf,AspNetCore.Docs,async,authelia,autocomplete,automerge-classic,avatarify-python,awesome-compose,Awesome-CV,CocoaLumberjack,code-server,commander.js,commitlint,compiler-explorer,components,compose,comprehensive-rust,CopyTranslator,core,core,coreui-free-bootstrap-admin-t
#
#
# Contributor: dependabot-preview[bot], Contributions: 118, Contributed Repos: opensource.guide,openzeppelin-contracts,parse-server,phpstan,mastodon,material-ui,mathjs,mkdocs-material,monica,JSVerbalExpressions,KaTeX,koel,kubo,mybatis-3,mybatis-plus,navi,RSSHub,ruffle,pure,pydantic,RxJava,sage,saleor,server,shadowsocks-windows,shepherd,react-bootstrap,react-dnd,react-flow,react-helmet,react-native-windows,Reactive-Resume,podman,posthog,PowerShell,prettier,starship,static-analysis,storybook,storybook,superset,syncthing,shields,Signal-Desktop,slate,slim,Slim,spotify-tui,vuepress,wasmer,webpack,wtf,tabby,tabler,tailwindcss,taro,xterm.js,yew,uuid,vant-weapp,verdaccio,dashboard,decap-cms,delta,diem,directus,discourse,backstage,bat,ant-design-pro,appium,authelia,aiohttp,ajv,allennlp,animate.css,bootstrap,bootstrap-table,brew,Cachet,compose,core,core,cube,chakra-ui,cheerio,Ciphey,CleanArchitecture,click,G2,gitmoji,gitui,gogs,golangci-lint,dokku,dolt,DPlayer,edex-ui,intro.js,java-design-patterns,graphiql,halo,filebrowser,Files,flask,flipper,forem,formatjs,freqtrade,hexo,hls.js,hoppscotch,hyper,
#
#
# Contributor: github-actions[bot], Contributions: 117, Contributed Repos: xstate,zellij,tauri,thanos,verdaccio,voyager,turbo,type-challenges,ui,upptime,uppy,motion-canvas,n8n,maui,medusa,micro,mobx,LunarVim,lvgl,marko,MaterialDesignInXamlToolkit,matomo,laravel-permission,leetcode,legado,lenster,linux-command,lit,nixpkgs,nocodb,nodebestpractices,nuxt,NvChad,OpenAPI-Specification,js-cookie,jupyterlab,k3s,kit,outline,shields,simple-icons,slate,source-code-hunter,spaCy,redux-devtools,refine,remix,renovate,rrweb,RSSHub,pipenv,playwright,Polly,rxdb,selectize.js,sequelize,server,sst,starship,SummaryOfLoanSuspension,SwiftLint,react,react-pdf,react-router,react-select,generator-jhipster,Ghost,github-readme-stats,hls.js,HowToCook,ice,distroless,docker-elk,docker-mailserver,editor.js,electron-builder,iptv,ish,jib,joplin,fabric.js,fastapi,gradio,graphiql,Grasscutter,headscale,firefox-ios,fnm,formik,axios,axios,backstage,Bilibili-Evolved,blitz,act,AFFiNE,aiohttp,dashy,developer-roadmap,dio,discord.py,ant-design,apollo-server,argo-cd,argo-workflows,asdf,astro,CodeEdit,ColossalAI,compiler-explore
#
#
# Contributor: renovate[bot], Contributions: 104, Contributed Repos: hls.js,immich,gatsby,Ghost,glances,glide,golangci-lint,jellyfin,jenkins,joplin,fnm,formatjs,freeCodeCamp,element-plus,gradio,grafana,grpc-gateway,electron-builder,node-http-proxy,NodeBB,novu,nowinandroid,nuxt,okhttp,jsdoc,KaTeX,kibana,kit,koel,ktor,mybatis-3,nest,NeteaseCloudMusicApi,mdx,mermaid,linux-command,localstack,openzeppelin-contracts,peerjs,phpstan,picasso,material-ui,alist,angular-cli,backstage,chakra-ui,chartist,ant-design-vue,apollo-client,apollo-server,appium,authelia,dash,decap-cms,devdocs,directus,code-server,commitlint,components,compose-samples,coreutils,cypress,cz-cli,bootstrap-vue,simple-icons,spring-boot-admin,react-bootstrap,react-spring,react-use,reactotron,rxdb,sage,semantic-release,sequelize,pnpm,podman,prettier,prisma,squoosh,starship,stencil,swagger-ui,sweetalert2,redux-devtools,redwood,renovate,retrofit,rollup,RSSHub,ruffle,verdaccio,Vim,vite,yarn,yup,vueuse,webrtc,webtorrent,wp-calypso,trpc,turbo,typescript-eslint,tachiyomi,tauri
#
#
# Contributor: greenkeeperio-bot, Contributions: 66, Contributed Repos: formatjs,freecodecamp.cn,graphiql,graphql-js,hackathon-starter,hls.js,html5-boilerplate,hyper,inferno,feathers,Ghost,gitmoji,edex-ui,electron-builder,electron-react-boilerplate,ivideo,mustache.js,next.js,next.js,material-design-lite,parse-server,js-cookie,jsPDF,Kap,karma,keystone-classic,less.js,lint-staged,lodash,nock,node-redis,meteor,Modernizr,webtorrent,wechaty,upterm,video.js,volkswagen,ts-node,ui-router,standard,stf,redux-form,redux-persist,request,rollup,react-boilerplate,react-color,react-redux-universal-hot-example,pkg,pnpm,postgraphile,pouchdb,preact,single-spa,semantic-release,Semantic-UI-React,sequelize,pure,core,css,cz-cli,ajv,dashboard,apollo-client,apollo-server
#
#
# Contributor: greenkeeper[bot], Contributions: 61, Contributed Repos: aos,apollo-client,apollo-server,appium,carbon,cheerio,chromeless,coc.nvim,babel,best-resume-ever,dashboard,core,ajv,ts-node,typescript-eslint,ui-router,video.js,webtorrent,wechaty,ws,Inquirer.js,highlight.js,flipper,framework7,graphiql,graphql-js,edex-ui,fastify,feathers,meteor,mkdocs-material,monica,parse-server,next.js,next.js,lowdb,marko,material-components-web,mathjs,nock,normalizr,js-cookie,jsdoc,jsPDF,KaTeX,lint-staged,pure,react-beautiful-dnd,react-dates,react-native-gifted-chat,standard,sweetalert2,swiper,rxdb,semantic-release,sequelize,shepherd,pnpm,pouchdb,shields,showdown
#
#
# Contributor: eltociear, Contributions: 46, Contributed Repos: impress.js,faiss,gpt4all,gpt4free,guidance,dragonfly,EasySpider,FiraCode,JARVIS,zincsearch,wechat-chatgpt,trilium,unilm,lama-cleaner,langchain,layui,llama_index,nodemailer,openai-cookbook,dalai,AgentGPT,AI-For-Beginners,alpaca-lora,codon,ControlNet,bun,chatbox,ChatGLM-6B,chatgpt-google-extension,chatgpt-retrieval-plugin,Ciphey,babyagi,annotated_deep_learning_paper_implementations,Apollo-11,stablediffusion,StableLM,stanford_alpaca,starship,roop,pytorch-CycleGAN-and-pix2pix,qdrant,react,pkg,project-guidelines,project-layout,segment-anything
#
#
# Contributor: renovate-bot, Contributions: 43, Contributed Repos: Ciphey,ant-design-vue,apollo-client,apollo-server,appium,backstage,code-server,commitlint,cypress,cz-cli,devdocs,amphtml,angular,angular-cli,rxdb,react-beautiful-dnd,react-use,swagger-ui,renovate,pnpm,prisma,spring-boot-admin,nest,NeteaseCloudMusicApi,meteor,microservices-demo,jsdoc,phpstan,linux-command,NodeBB,nowinandroid,webrtc,webtorrent,yup,verdaccio,Vim,freeCodeCamp,Ghost,go-redis,grpc-gateway,electron-react-boilerplate,etcher,hls.js
#
#
# Contributor: 0xflotus, Contributions: 41, Contributed Repos: markdown-it,mars,masscan,PapaParse,micro,MMKV,just,lint-staged,nlp-tutorial,octotree,sql.js,sweetalert,pure,sampler,remotion,simdjson,slidev,prisma,professional-programming,ice,ink,fnm,interact.js,Iosevka,face-api.js,edex-ui,editor.js,uuid,zincsearch,tabler-icons,wenyan,wttr.in,typesense,arthas,codelf,awesome-oss-alternatives,bert,cheat.sh,clip-as-service,DeOldify,blurhash
#
#
# Contributor: allcontributors[bot], Contributions: 41, Contributed Repos: watchtower,tabby,trpc,linkedin-skill-assessments-quizzes,livewire,p5.js,nerd-fonts,night,nocodb,nodebestpractices,oh-my-posh,rustlings,starship,spotify-tui,react,react-testing-library,qdrant,query,questdb,responsively-app,docker-mailserver,downshift,echo,intro.js,java-design-patterns,javascript-testing-best-practices,ent,foam,hoppscotch,How-To-Ask-Questions-The-Smart-Way,CodeEdit,codesandbox-client,CopyTranslator,create-react-native-app,chakra-ui,Ciphey,coc.nvim,budibase,carbon,alist,authelia

# %%
import mysql.connector

# Établir une connexion à la base de données MySQL
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="github"
)

# Créer un curseur pour exécuter des requêtes
cursor = conn.cursor()

# Requête SQL à exécuter
query = """
SELECT Language.name, COUNT(*) AS LanguageCount
FROM RepoLanguage
INNER JOIN Language ON RepoLanguage.language_id = Language.id
GROUP BY Language.name
ORDER BY LanguageCount DESC
LIMIT 10;
"""

# Exécuter la requête SQL
cursor.execute(query)

# Récupérer les résultats de la requête
results = cursor.fetchall()

# Afficher les résultats
for row in results:
    language_name = row[0]
    language_count = row[1]
    print(f"Language: {language_name}, Count: {language_count}")

# Fermer le curseur et la connexion
cursor.close()
conn.close()
# Out:
# Language: Shell, Count: 1337
# Language: JavaScript, Count: 1289
# Language: HTML, Count: 1050
# Language: Python, Count: 839
# Language: CSS, Count: 783
# Language: Dockerfile, Count: 655
# Language: Makefile, Count: 597
# Language: TypeScript, Count: 563
# Language: C, Count: 399
# Language: C++, Count: 350
